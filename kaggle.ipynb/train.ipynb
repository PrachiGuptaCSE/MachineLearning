# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("train.csv")
df1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
dfle=df1
cols=['LotFrontage','MSZoning','Street','Alley','LotShape','LandContour','Utilities','LotConfig','Neighborhood','LandSlope','Condition1','Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence','MiscFeature','SaleType','SaleCondition']
for col in cols:
    dfle[col]=le.fit_transform(dfle[col])
    dfle

# %%
dfle['LotFrontage']=dfle['LotFrontage'].fillna(dfle['LotFrontage'].median())

# %%
dfle['GarageYrBlt']=dfle['GarageYrBlt'].fillna(dfle['GarageYrBlt'].median())

# %%
dfle['MasVnrArea']=dfle['MasVnrArea'].fillna(dfle['MasVnrArea'].median())

# %%
X=dfle.drop(['SalePrice','Id'],axis='columns')
X
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0             60         3           36     8450       1      2         3
# 1             20         3           51     9600       1      2         3
# 2             60         3           39    11250       1      2         0
# 3             70         3           31     9550       1      2         0
# 4             60         3           55    14260       1      2         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1455          60         3           33     7917       1      2         3
# 1456          20         3           56    13175       1      2         3
# 1457          70         3           37     9042       1      2         3
# 1458          20         3           39     9717       1      2         3
# 1459          20         3           46     9937       1      2         3
#
#       LandContour  Utilities  LotConfig  ...  ScreenPorch  PoolArea  PoolQC  \
# 0               3          0          4  ...            0         0       3
# 1               3          0          2  ...            0         0       3
# 2               3          0          4  ...            0         0       3
# 3               3          0          0  ...            0         0       3
# 4               3          0          2  ...            0         0       3
# ...           ...        ...        ...  ...          ...       ...     ...
# 1455            3          0          4  ...            0         0       3
# 1456            3          0          4  ...            0         0       3
# 1457            3          0          4  ...            0         0       3
# 1458            3          0          4  ...            0         0       3
# 1459            3          0          4  ...            0         0       3
#
#       Fence  MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0         4            4        0       2    2008         8              4
# 1         4            4        0       5    2007         8              4
# 2         4            4        0       9    2008         8              4
# 3         4            4        0       2    2006         8              0
# 4         4            4        0      12    2008         8              4
# ...     ...          ...      ...     ...     ...       ...            ...
# 1455      4            4        0       8    2007         8              4
# 1456      2            4        0       2    2010         8              4
# 1457      0            2     2500       5    2010         8              4
# 1458      4            4        0       4    2010         8              4
# 1459      4            4        0       6    2008         8              4
#
# [1460 rows x 79 columns]

# %%
y=dfle.SalePrice
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
dfle.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
null_counts=dfle.isnull().sum()
print(null_counts[null_counts>0])
# Out:
# Series([], dtype: int64)

# %%
model.predict(X_test)
# Out:
# array([168675.80173091, 123925.14200098, 151318.70455312, 143693.46553219,
#         70214.50145932, 306378.86467632, 163065.67744109, 144798.99375882,
#        213671.70652388, 220377.24668076, 160837.19111572, 116835.80591202,
#        169331.88473827, 125016.5208034 , 174390.53594561,  92534.57191075,
#        134258.89795191, 100691.33295826, 137282.88836446, 113437.5801143 ,
#        203299.79335015, 164616.13412641,  95053.85081069, 181039.00637334,
#        131577.12342046, 352948.40929189, 174823.82113195, 200011.35185057,
#         41525.4092645 , 277320.89193108, 154196.8532139 , 130835.00761627,
#        271479.24052597, 145029.27570958,  91475.54576646, 262163.72058785,
#        341816.49403745,  89888.67452563, 228198.67372093,  60981.19280179,
#        230358.50933381, 215185.78089601, 101419.90518898,  74820.1578166 ,
#         75601.26370085, 115554.42198561, 104263.80643483, 142248.04822274,
#        351132.80188663, 264910.904592  , 192285.03707847, 210319.70762218,
#        312430.31948951,  87233.65981207, 142712.97278886, 213914.13502932,
#        211440.99201011, 121299.18246497, 181953.84845995, 225111.43009934,
#        160425.27947926, 132669.12393183, 163671.85998854, 110612.63672124,
#        128009.96185779, 176360.57970935, 139371.86577368, 295775.29238155,
#        105959.39014576, 193296.16134064, 132628.32095758, 157973.27752583,
#        143703.19749387, 166377.2048    , 238862.42626732, 297131.90874989,
#        113501.48027624, 200962.04022289, 233511.73509181, 301337.29971696,
#        312186.18599606, 316772.87459867, 304279.44311919, 188409.41375388,
#         92195.44576394, 183221.02255496,  84434.60451979, 212967.40282884,
#        199917.2233743 , 250467.94192697, 106399.13713194, 153299.36953418,
#        169853.85525872, 173932.33932288, 193367.79170269, 121953.5355238 ,
#         97924.90796097, 208289.28368768, 170387.87844845, 242273.23336194,
#        270575.10026858, 190681.5210206 , 224920.62910298, 231882.83424965,
#        172119.05698881, 200253.09294185, 180876.34572652,  72969.12891808,
#        416347.59837679, 142807.6403781 , 123046.20480962, 247543.50813211,
#        272396.72258079, 127925.22643002, 327615.08895683, 192043.7751816 ,
#        199267.52646654, 109382.6721278 , 169036.08180491, 131589.77208076,
#        308706.47646953, 147881.72552463, 128044.383613  , 161398.16157437])

# %%
model.score(X_test,y_test)
# Out:
# 0.763004889696616

# %%
df2=pd.read_csv("test.csv")
df2.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
# 3       0      6    2010        WD         Normal
# 4       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
dfle2=df2
cols=['LotFrontage','MSZoning','Street','Alley','LotShape','LandContour','Utilities','LotConfig','Neighborhood','LandSlope','Condition1','Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence','MiscFeature','SaleType','SaleCondition']
for col in cols:
    dfle2[col]=le.fit_transform(dfle2[col])
    dfle2

# %%
dfle2['LotFrontage']=dfle['LotFrontage'].fillna(dfle2['LotFrontage'].median())

# %%
dfle2['GarageYrBlt']=dfle['GarageYrBlt'].fillna(dfle2['GarageYrBlt'].median())

# %%
dfle2['MasVnrArea']=dfle['MasVnrArea'].fillna(dfle2['MasVnrArea'].median())

# %%
dfle2
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     1461          20         2           36    11622       1      2
# 1     1462          20         3           51    14267       1      2
# 2     1463          60         3           39    13830       1      2
# 3     1464          60         3           31     9978       1      2
# 4     1465         120         3           55     5005       1      2
# ...    ...         ...       ...          ...      ...     ...    ...
# 1454  2915         160         4           33     1936       1      2
# 1455  2916         160         4           33     1894       1      2
# 1456  2917          20         3           56    20000       1      2
# 1457  2918          85         3           37    10441       1      2
# 1458  2919          60         3           39     9627       1      2
#
#       LotShape  LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  \
# 0            3            3          0  ...          120         0       2
# 1            0            3          0  ...            0         0       2
# 2            0            3          0  ...            0         0       2
# 3            0            3          0  ...            0         0       2
# 4            0            1          0  ...          144         0       2
# ...        ...          ...        ...  ...          ...       ...     ...
# 1454         3            3          0  ...            0         0       2
# 1455         3            3          0  ...            0         0       2
# 1456         3            3          0  ...            0         0       2
# 1457         3            3          0  ...            0         0       2
# 1458         3            3          0  ...            0         0       2
#
#       Fence  MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0         2            3        0       6    2010         8              4
# 1         4            0    12500       6    2010         8              4
# 2         2            3        0       3    2010         8              4
# 3         4            3        0       6    2010         8              4
# 4         4            3        0       1    2010         8              4
# ...     ...          ...      ...     ...     ...       ...            ...
# 1454      4            3        0       6    2006         8              4
# 1455      4            3        0       4    2006         8              0
# 1456      4            3        0       9    2006         8              0
# 1457      2            2      700       7    2006         8              4
# 1458      4            3        0      11    2006         8              4
#
# [1459 rows x 80 columns]

# %%
model.predict(X)
# Out:
# array([213387.88935949, 196847.42894042, 217366.72847177, ...,
#        252769.2704531 , 151868.81441058, 166628.39371748], shape=(1460,))

# %%
model.score(X,y)
# Out:
# 0.843270004113537

# %%
import pandas as pd
Test_data=pd.read_csv('test.csv') 
X_test=Test_data.drop(columns=['Id'])

# Make predictions
predictions = model.predict(X_test)

# Create DataFrame
submission = pd.DataFrame({
    'SalePrice': predictions,
  'Id': Test_data['Id'],
})

# Save to CSV
submission.to_csv('submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[135], line 6
#       2 Test_data=pd.read_csv('test.csv')
#       3 X_test=Test_data.drop(columns=['Id'])
#       4
#       5 # Make predictions
# ----> 6 predictions = model.predict(X_test)
#       7
#       8 # Create DataFrame
#       9 submission = pd.DataFrame({
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_base.py:277, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
#     275     check_is_fitted(self)
# --> 277     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     278     coef_ = self.coef_
#     279     if coef_.ndim == 1:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2954, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2952         out = X, y
#    2953 elif not no_val_X and no_val_y:
# -> 2954     out = check_array(X, input_name="X", **check_params)
#    2955 elif no_val_X and not no_val_y:
#    2956     out = _check_y(y, **check_params)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:105, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     103 if not is_array_api and X.dtype == np.dtype("object") and not allow_nan:
#     104     if _object_dtype_isnan(X).any():
# --> 105         raise ValueError("Input contains NaN")
#     107 # We need only consider float arrays, hence can early return for all else.
#     108 if not xp.isdtype(X.dtype, ("real floating", "complex floating")):
#
# ValueError: Input contains NaN
